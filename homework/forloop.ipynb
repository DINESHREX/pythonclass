# %%
l = [1,2,3,4,4,3,2,1,5,6]
u =[]
for i in l:
    if i not in u:
        u.append(i)
    else:
        pass
print(u)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l = [1,2,3,4,4,3,2,1,5,6,4]
c_d={}
for num in l:
    if num in c_d:
        c_d[num]+=1
    else:
         c_d[num]=1

# print(c_d)

for key,values in c_d.items():
    print(f"{key} : {values}")
# Out:
# 1 : 2
# 2 : 2
# 3 : 2
# 4 : 3
# 5 : 1
# 6 : 1
