# %%
container = 1
con_tainer=1
_contai_ner=1
contaIner=1
CONTAINER=1
CONTAINER1 =1
print(container,con_tainer,_contai_ner,contaIner,CONTAINER,CONTAINER1)
# Out:
# 1 1 1 1 1 1

# %%
1container = 1
@container=1
contai-ner=1
conta iner=1
print(1container,@container,contai-ner,conta iner)
# Out:
#   Cell In[2], line 1
#     1container = 1
#     ^
# SyntaxError: invalid decimal literal
