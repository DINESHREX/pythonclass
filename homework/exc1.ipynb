# %%
l=[]
for i in range(12):
    if i not in l:
        l.append(i)
print(sum(l))
# Out:
# 66

# %%
num =123
rnum = str(num)
print(rnum[::-1])
# Out:
# 321

# %%
word ="hello"
vowels=['a','e','i','o','u','A','E','I','O','U']
count =0
for i in word:
    if i in vowels:
        count+=1
print(count)
# Out:
# 2

# %%
n = 2
for i in range(1, 11):
    print(f"{i}*{n}= {i * n}")
# Out:
# 1*2= 2
# 2*2= 4
# 3*2= 6
# 4*2= 8
# 5*2= 10
# 6*2= 12
# 7*2= 14
# 8*2= 16
# 9*2= 18
# 10*2= 20

# %%
pal = "madam"
palr= pal[::-1]
if pal == palr:
    print("Its a Palindrome")
else:
    print("Its Not a Palindrome")
# Out:
# Its a Palindrome

# %%
fact =1
for i in range(1,11):
    fact*=i
    print(fact)
# Out:
# 1
# 2
# 6
# 24
# 120
# 720
# 5040
# 40320
# 362880
# 3628800
