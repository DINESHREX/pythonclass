# %%
ml = [10, "apple", 25, "banana", 40, "cherry", 55, "mango", 70, "grape"]
ml[2]="Orange"
print(ml)
# Out:
# [10, 'apple', 'Orange', 'banana', 40, 'cherry', 55, 'mango', 70, 'grape']

# %%
ml = [10, "apple", 25, "banana", 40, "cherry", 55, "mango", 70, "grape"]
ml.pop()
print(ml)
# Out:
# [10, 'apple', 25, 'banana', 40, 'cherry', 55, 'mango', 70]

# %%
ml = [10, "apple", 25, "banana", 40, "cherry", 55, "mango", 70, "grape"]
nl = [100, "pineapple", 200]
ml.extend(nl)
print(ml)
# Out:
# [10, 'apple', 25, 'banana', 40, 'cherry', 55, 'mango', 70, 'grape', 100, 'pineapple', 200]

# %%
ml = [10, "apple", 25, "banana", 40, "cherry", 55, "mango", 70, "grape"]
ml.remove("banana")
print(ml)
# Out:
# [10, 'apple', 25, 40, 'cherry', 55, 'mango', 70, 'grape']
