# %%
l = [10, 45, 23, 89, 12]

print("Maximum:", max(l))
print("Minimum:", min(l))
# Out:
# Maximum: 89
# Minimum: 10

# %%
l = [10, 45, 23, 89, 12]

l.sort()
print("Second Largest:", l[-2])
# Out:
# Second Largest: 45

# %%
l = [10, 45, 23, 89, 12]

print("Second Smallest:", sorted(l)[1])
# Out:
# Second Smallest: 12
