# %%
# string methods

n = "python"
print(n.upper())
print(n.lower())
print(n.capitalize())
print(n.title())
print(n.swapcase())
# Out:
# PYTHON
# python
# Python
# Python
# PYTHON

# %%
# check methods

"12334".isdigit()
"abc".isalpha()
"abc123".isalnum()
" ".isspace()
"python".islower()
"PYTHON".isupper()
# Out:
# True

# %%
# search and replace
s="Hello world"
s.find("world")
# Out:
# 6

# %%
s.index("Hello")
# Out:
# 0

# %%
s.count("l")
# Out:
# 3

# %%
s.replace("world","Python")
# Out:
# 'Hello Python'

# %%
#Split & join

d = "a,b,c"
d.split(",")
# Out:
# ['a', 'b', 'c']

# %%
lst = ['a','b','c']
",".join(lst)
# Out:
# 'a,b,c'

# %%
st ="  hello  "
st.strip()
# Out:
# 'hello'

# %%
st ="  hello  "
st.lstrip()
# Out:
# 'hello  '

# %%
st ="  hello  "
st.rstrip()
# Out:
# '  hello'
