# %%
b ="hello world"
print(b[6:])
# Out:
# world

# %%
b ="hello world!"
print(b[-6:-1])
# Out:
# world

# %%
b ="how are you"
print(b[4:7])
# Out:
# are

# %%
b ="how are you"
print(b[2:5])
# Out:
# w a

# %%
b ="how are you"
print(b[-5:-2])
# Out:
# e y
