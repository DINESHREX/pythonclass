# %%
a=int(input("Enter the Value 1"))
b=int(input("Enter the Value 2"))
c=int(input("Enter the Value 3"))

if a>b and a>c:
    print(f"Value {a} is greater")
elif b>c and b>a:
    print(f"Value {b} is greater")
else:
     print(f"Value {c} is greater")
# Out:
# Enter the Value 1 90
# Enter the Value 2 80
# Enter the Value 3 67
# Value 90 is greater
