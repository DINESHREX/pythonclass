# %%
l=[1,2,3,4,5,6,7,8]
l[2:5]="Hi"
l

# %%
d={1,2,3,4}
d.add(86)
print(d)

# %%
n=(5,6,7,8)
m=list(n)
m.remove(6)
print(m)
# Out:
# [5, 7, 8]

# %%
t={"Hi":7,"Hello":8}
t["Hello"] = 10
print(t)
# Out:
# {'Hi': 7, 'Hello': 10}

# %%
t={"Hi":7,"Hello":8}
t.update({"Hello":10})
print(t)
# Out:
# {'Hi': 7, 'Hello': 10}

# %%
l=[2,5,"hi",[5,6,7],7]
print(l[3][1])
# Out:
# 6

# %%
l=[2,5,"hi",[5,6,[1,2,5],7],7]
print(l[3][2][1])
# Out:
# 2
