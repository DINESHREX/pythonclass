# %%
import pandas as pd
data = pd.read_csv("markndata.csv")
data
# Out:
#      student_id   tam   eng   math  science  social  total grade
# 0           1.0  69.0  51.0   47.0     79.0    49.0    NaN     F
# 1           2.0  79.0   NaN   65.0     43.0    70.0  309.0     D
# 2           3.0  43.0  64.0  100.0     36.0    84.0  327.0     D
# 3           4.0  85.0  54.0   91.0     57.0     NaN  330.0     D
# 4           NaN  98.0  78.0   59.0     51.0     NaN  350.0     C
# ..          ...   ...   ...    ...      ...     ...    ...   ...
# 495       496.0  49.0   NaN   36.0      NaN    90.0  261.0   NaN
# 496       497.0  61.0  69.0   57.0     95.0    77.0  359.0     C
# 497       498.0  50.0   NaN   77.0     74.0    75.0  312.0     D
# 498       499.0  63.0   NaN   50.0     81.0    91.0    NaN     C
# 499       500.0   NaN  90.0   74.0     53.0    63.0  354.0     C
#
# [500 rows x 8 columns]

# %%
data.head(10)
# Out:
#    student_id   tam   eng   math  science  social  total grade
# 0         1.0  69.0  51.0   47.0     79.0    49.0    NaN     F
# 1         2.0  79.0   NaN   65.0     43.0    70.0  309.0     D
# 2         3.0  43.0  64.0  100.0     36.0    84.0  327.0     D
# 3         4.0  85.0  54.0   91.0     57.0     NaN  330.0     D
# 4         NaN  98.0  78.0   59.0     51.0     NaN  350.0     C
# 5         6.0  94.0   NaN   79.0     45.0    53.0  371.0     C
# 6         7.0  53.0  91.0   36.0     80.0    50.0  310.0     D
# 7         NaN  42.0   NaN   57.0     49.0    99.0  319.0     D
# 8         9.0  54.0  54.0   47.0      NaN    43.0  233.0     F
# 9         NaN  99.0  61.0   69.0     73.0     NaN  398.0     C

# %%
data.tail(10)
# Out:
#      student_id   tam   eng  math  science  social  total grade
# 490       491.0  58.0  36.0  38.0     92.0     NaN  265.0     F
# 491       492.0  44.0  90.0  90.0     65.0    43.0  332.0     D
# 492       493.0  71.0  75.0  84.0     99.0    36.0    NaN     C
# 493       494.0   NaN  42.0  83.0     38.0    36.0    NaN     F
# 494       495.0  42.0  95.0  77.0     46.0    62.0    NaN   NaN
# 495       496.0  49.0   NaN  36.0      NaN    90.0  261.0   NaN
# 496       497.0  61.0  69.0  57.0     95.0    77.0  359.0     C
# 497       498.0  50.0   NaN  77.0     74.0    75.0  312.0     D
# 498       499.0  63.0   NaN  50.0     81.0    91.0    NaN     C
# 499       500.0   NaN  90.0  74.0     53.0    63.0  354.0     C

# %%
data.describe()
# Out:
#        student_id         tam         eng       math     science      social  \
# count  450.000000  441.000000  432.000000  456.00000  455.000000  450.000000
# mean   256.382222   67.052154   65.076389   67.14693   67.683516   66.051111
# std    143.333929   19.052547   19.045341   19.12924   19.293606   18.584055
# min      1.000000   35.000000   35.000000   35.00000   35.000000   35.000000
# 25%    134.500000   51.000000   49.000000   50.00000   51.000000   50.000000
# 50%    257.500000   67.000000   64.000000   68.00000   68.000000   65.000000
# 75%    380.750000   84.000000   81.250000   83.25000   85.000000   81.750000
# max    500.000000  100.000000  100.000000  100.00000  100.000000  100.000000
#
#             total
# count  440.000000
# mean   334.840909
# std     41.533390
# min    221.000000
# 25%    307.750000
# 50%    336.000000
# 75%    362.000000
# max    437.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   student_id  450 non-null    float64
#  1   tam         441 non-null    float64
#  2   eng         432 non-null    float64
#  3   math        456 non-null    float64
#  4   science     455 non-null    float64
#  5   social      450 non-null    float64
#  6   total       440 non-null    float64
#  7   grade       450 non-null    object
# dtypes: float64(7), object(1)
# memory usage: 31.4+ KB

# %%
data.isnull()
# Out:
#      student_id    tam    eng   math  science  social  total  grade
# 0         False  False  False  False    False   False   True  False
# 1         False  False   True  False    False   False  False  False
# 2         False  False  False  False    False   False  False  False
# 3         False  False  False  False    False    True  False  False
# 4          True  False  False  False    False    True  False  False
# ..          ...    ...    ...    ...      ...     ...    ...    ...
# 495       False  False   True  False     True   False  False   True
# 496       False  False  False  False    False   False  False  False
# 497       False  False   True  False    False   False  False  False
# 498       False  False   True  False    False   False   True  False
# 499       False   True  False  False    False   False  False  False
#
# [500 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# student_id    50
# tam           59
# eng           68
# math          44
# science       45
# social        50
# total         60
# grade         50
# dtype: int64

# %%
xs =data["studentid"].median()
print(xs)
data["studentid"].fillna(xs, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'studentid'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 xs =data["studentid"].median()
# ...

# %%
x11 =data["tam"].mean()
print(x11)
# Out:
# 67.05215419501134

# %%
data["tam"].fillna(data["tam"].mean(), inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3792\4050955756.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["tam"].fillna(data["tam"].mean(), inplace=True)

# %%
x12 =data["eng"].mean()
print(x12)
# Out:
# 65.07638888888889

# %%
data["eng"].fillna(x12, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3792\2074844808.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["eng"].fillna(x12, inplace=True)

# %%
x13 =data["math"].mean()
print(x13)
# Out:
# 67.1469298245614

# %%
data["math"].fillna(x13, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3792\2319610617.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["math"].fillna(x13, inplace=True)

# %%
x14 =data["science"].mean()
print(x14)
# Out:
# 67.68351648351648

# %%
data["science"].fillna(x14, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3792\2568950359.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["science"].fillna(x14, inplace=True)

# %%
x15 =data["social"].mean()
print(x15)
# Out:
# 66.05111111111111

# %%
data["social"].fillna(x15, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3792\1914929754.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["social"].fillna(x15, inplace=True)

# %%
x16 =data["total"].mean()
print(x16)
# Out:
# 334.84090909090907

# %%
data["total"].fillna(x16, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3792\2782192157.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["total"].fillna(x16, inplace=True)

# %%
x17 =data["grade"].mode()[0]
print(x17)
data["grade"].fillna(x17, inplace=True)
# Out:
# D
# C:\Users\user\AppData\Local\Temp\ipykernel_3792\499124639.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["grade"].fillna(x17, inplace=True)

# %%
data["grade"].replace("D", "Poor", inplace =True)
data
# Out:
#      student_id        tam        eng   math    science     social  \
# 0           1.0  69.000000  51.000000   47.0  79.000000  49.000000
# 1           2.0  79.000000  65.076389   65.0  43.000000  70.000000
# 2           3.0  43.000000  64.000000  100.0  36.000000  84.000000
# 3           4.0  85.000000  54.000000   91.0  57.000000  66.051111
# 4           NaN  98.000000  78.000000   59.0  51.000000  66.051111
# ..          ...        ...        ...    ...        ...        ...
# 495       496.0  49.000000  65.076389   36.0  67.683516  90.000000
# 496       497.0  61.000000  69.000000   57.0  95.000000  77.000000
# 497       498.0  50.000000  65.076389   77.0  74.000000  75.000000
# 498       499.0  63.000000  65.076389   50.0  81.000000  91.000000
# 499       500.0  67.052154  90.000000   74.0  53.000000  63.000000
#
#           total grade
# 0    334.840909     F
# 1    309.000000  Poor
# 2    327.000000  Poor
# 3    330.000000  Poor
# 4    350.000000     C
# ...

# %%
data.replace("F", "Very Poor")
# Out:
#      student_id        tam        eng   math    science     social  \
# 0           1.0  69.000000  51.000000   47.0  79.000000  49.000000
# 1           2.0  79.000000  65.076389   65.0  43.000000  70.000000
# 2           3.0  43.000000  64.000000  100.0  36.000000  84.000000
# 3           4.0  85.000000  54.000000   91.0  57.000000  66.051111
# 4           NaN  98.000000  78.000000   59.0  51.000000  66.051111
# ..          ...        ...        ...    ...        ...        ...
# 495       496.0  49.000000  65.076389   36.0  67.683516  90.000000
# 496       497.0  61.000000  69.000000   57.0  95.000000  77.000000
# 497       498.0  50.000000  65.076389   77.0  74.000000  75.000000
# 498       499.0  63.000000  65.076389   50.0  81.000000  91.000000
# 499       500.0  67.052154  90.000000   74.0  53.000000  63.000000
#
#           total      grade
# 0    334.840909  Very Poor
# 1    309.000000       Poor
# 2    327.000000       Poor
# 3    330.000000       Poor
# ...

# %%
# column selection
data["tam"]
# Out:
# 0      69.000000
# 1      79.000000
# 2      43.000000
# 3      85.000000
# 4      98.000000
#          ...
# 495    49.000000
# 496    61.000000
# 497    50.000000
# 498    63.000000
# 499    67.052154
# Name: tam, Length: 500, dtype: float64

# %%
# Multi column selection
data[["tam","eng","math","grade"]]
# Out:
#            tam        eng   math grade
# 0    69.000000  51.000000   47.0     F
# 1    79.000000  65.076389   65.0  Poor
# 2    43.000000  64.000000  100.0  Poor
# 3    85.000000  54.000000   91.0  Poor
# 4    98.000000  78.000000   59.0     C
# ..         ...        ...    ...   ...
# 495  49.000000  65.076389   36.0  Poor
# 496  61.000000  69.000000   57.0     C
# 497  50.000000  65.076389   77.0  Poor
# 498  63.000000  65.076389   50.0     C
# 499  67.052154  90.000000   74.0     C
#
# [500 rows x 4 columns]

# %%
# condition filtering
data[data["grade"] == "Poor"]
# Out:
#      student_id   tam        eng   math    science     social       total  \
# 1           2.0  79.0  65.076389   65.0  43.000000  70.000000  309.000000
# 2           3.0  43.0  64.000000  100.0  36.000000  84.000000  327.000000
# 3           4.0  85.0  54.000000   91.0  57.000000  66.051111  330.000000
# 6           7.0  53.0  91.000000   36.0  80.000000  50.000000  310.000000
# 7           NaN  42.0  65.076389   57.0  49.000000  99.000000  319.000000
# ..          ...   ...        ...    ...        ...        ...         ...
# 488       489.0  56.0  59.000000   53.0  80.000000  70.000000  334.840909
# 491       492.0  44.0  90.000000   90.0  65.000000  43.000000  332.000000
# 494       495.0  42.0  95.000000   77.0  46.000000  62.000000  334.840909
# 495       496.0  49.0  65.076389   36.0  67.683516  90.000000  261.000000
# 497       498.0  50.0  65.076389   77.0  74.000000  75.000000  312.000000
#
#     grade
# 1    Poor
# 2    Poor
# 3    Poor
# 6    Poor
# 7    Poor
# ...

# %%
data.sort_values("total")
# Out:
#      student_id        tam        eng      math    science  social  total  \
# 375       376.0  38.000000  36.000000  45.00000  61.000000    41.0  221.0
# 367       368.0  51.000000  42.000000  67.14693  35.000000    59.0  222.0
# 248       249.0  67.052154  62.000000  41.00000  45.000000    36.0  223.0
# 449       450.0  44.000000  37.000000  41.00000  42.000000    65.0  229.0
# 8           9.0  54.000000  54.000000  47.00000  67.683516    43.0  233.0
# ..          ...        ...        ...       ...        ...     ...    ...
# 32         33.0  97.000000  71.000000  67.14693  99.000000    83.0  423.0
# 101       102.0  61.000000  94.000000  93.00000  88.000000    88.0  424.0
# 201       202.0  84.000000  96.000000  98.00000  90.000000    57.0  425.0
# 484       485.0  85.000000  65.076389  93.00000  74.000000    96.0  437.0
# 89         90.0  99.000000  50.000000  96.00000  94.000000    98.0  437.0
#
#     grade
# 375  Poor
# 367     F
# 248     F
# 449     F
# 8       F
# ...

# %%
data.sort_values("total", ascending = False)
# Out:
#      student_id        tam        eng      math    science  social  total  \
# 89         90.0  99.000000  50.000000  96.00000  94.000000    98.0  437.0
# 484       485.0  85.000000  65.076389  93.00000  74.000000    96.0  437.0
# 201       202.0  84.000000  96.000000  98.00000  90.000000    57.0  425.0
# 101       102.0  61.000000  94.000000  93.00000  88.000000    88.0  424.0
# 32         33.0  97.000000  71.000000  67.14693  99.000000    83.0  423.0
# ..          ...        ...        ...       ...        ...     ...    ...
# 8           9.0  54.000000  54.000000  47.00000  67.683516    43.0  233.0
# 449       450.0  44.000000  37.000000  41.00000  42.000000    65.0  229.0
# 248       249.0  67.052154  62.000000  41.00000  45.000000    36.0  223.0
# 367       368.0  51.000000  42.000000  67.14693  35.000000    59.0  222.0
# 375       376.0  38.000000  36.000000  45.00000  61.000000    41.0  221.0
#
#     grade
# 89      B
# 484     B
# 201     B
# 101     B
# 32      B
# ...

# %%
data.groupby("grade").sum()
# Out:
#        student_id           tam           eng          math       science  \
# grade
# B          5619.0   2204.208617   2087.305556   2320.440789   2239.417582
# C         33007.0   9815.678005   9293.680556   9948.763158   9941.619780
# F         19573.0   4959.469388   5088.993056   5089.322368   5188.151648
# Poor      57173.0  16546.721088  16068.215278  16214.938596  16472.569231
#
#              social         total
# grade
# B       2178.051111  11131.840909
# C       9773.715556  48822.250000
# F       5162.255556  25802.454545
# Poor   15911.533333  81663.909091

# %%
data.groupby("grade")["total"].mean()
# Out:
# grade
# B       412.290404
# C       367.084586
# F       286.693939
# Poor    326.655636
# Name: total, dtype: float64

# %%
data["Avg"] = data['total'] / 5
data
# Out:
#      student_id        tam        eng   math    science     social  \
# 0           1.0  69.000000  51.000000   47.0  79.000000  49.000000
# 1           2.0  79.000000  65.076389   65.0  43.000000  70.000000
# 2           3.0  43.000000  64.000000  100.0  36.000000  84.000000
# 3           4.0  85.000000  54.000000   91.0  57.000000  66.051111
# 4           NaN  98.000000  78.000000   59.0  51.000000  66.051111
# ..          ...        ...        ...    ...        ...        ...
# 495       496.0  49.000000  65.076389   36.0  67.683516  90.000000
# 496       497.0  61.000000  69.000000   57.0  95.000000  77.000000
# 497       498.0  50.000000  65.076389   77.0  74.000000  75.000000
# 498       499.0  63.000000  65.076389   50.0  81.000000  91.000000
# 499       500.0  67.052154  90.000000   74.0  53.000000  63.000000
#
#           total grade        Avg
# 0    334.840909     F  66.968182
# 1    309.000000  Poor  61.800000
# 2    327.000000  Poor  65.400000
# ...

# %%
cols = ["tam","eng","math","science","social","total","Avg"]
data[cols] = data[cols].round().astype(int)

# %%
data.to_html("output1.html")
