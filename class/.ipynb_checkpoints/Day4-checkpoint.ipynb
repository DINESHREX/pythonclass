# %%
# string methods

n = "python"
print(n.upper())
print(n.lower())
print(n.capitalize())
print(n.title())
print(n.swapcase())

# %%
# check methods

"12334".isdigit()
"abc".isalpha()
"abc123".isalnum()
" ".isspace()
"python".islower()
"PYTHON".isupper()

# %%
# search and replace
s="Hello world"
s.find("world")
