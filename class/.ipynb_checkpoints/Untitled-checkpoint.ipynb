# %%
dict ={
    "Arun": 9876543210,
    "Bala": 9876543211,
    "Charan": 9876543212,
    "Divya": 9876543213,
    "Esha": 9876543214,
    "Farhan": 9876543215,
    "Gokul": 9876543216,
    "Hari": 9876543217,
    "Ishaan": 9876543218,
    "Jaya": 9876543219}
while True:
    i = input("For search press s , To Quit press q : ")
    if i == "s":
        search = input("Enter The Name to search")
        for key, values in dict.items():
            if search in dict:
             print(search, ":", dict[search])
        else:
            print("Name not found")

    elif i == "q":
        print("Quit")
        break
    else:
        print("Enter The Valid Input")
# Out:
#   Cell In[1], line 18
#     print(search, ":", dict[search])
#     ^
# IndentationError: expected an indented block after 'if' statement on line 17
