# %%
i = 50 
while i>=30:
    print(i)
    i -= 1

# %%
i =50 
while i>=0:
    print(i)
    i -= 1

# %%
k=[1,2,3,4,5,6]
n=0
for i in k:
    print(f"{i}, index {n}")
    n+=1
# Out:
# 1, index 0
# 2, index 1
# 3, index 2
# 4, index 3
# 5, index 4
# 6, index 5

# %%
k=[1,2,3,4,5,6,7]
n=0
for i in k:
    n+=1
print(n)
# Out:
# 7
