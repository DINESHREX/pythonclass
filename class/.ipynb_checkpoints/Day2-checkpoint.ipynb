# %%
# Type Casting

k='hello'
print(type(k))
# Out:
# <class 'str'>

# %%
k=2
print(type(k))
# Out:
# <class 'int'>

# %%
k=False
print(type(k))
# Out:
# <class 'bool'>

# %%
k= 5.67
print(type(k))
# Out:
# <class 'float'>

# %%
k=1+7j
print(type(k))
# Out:
# <class 'complex'>

# %%
k1=1+77j
k3=str(k1)
print(k3)
# Out:
# (1+77j)
