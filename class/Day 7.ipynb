# %%
l=[1,2,3,4,5,6,7]
l[0]="Python"
print(l)
# Out:
# ['Python', 2, 3, 4, 5, 6, 7]

# %%
l=["Hi","2","Hello",75]
l[1]= 36
l.pop(2)
#l.remove("Hello")
l.append(86)
print(l)
# Out:
# ['Hi', 36, 75, 86]

# %%
l=["Hi","2","Hello"]
l.sort()
print(l)
# Out:
# ['2', 'Hello', 'Hi']
