# %%
a=6
b=12
def cal():
    c=a+b
    d=a-b
    print(c)
    print(d)
cal()
# Out:
# 18
# -6

# %%
a=6
b=12
def cal():
    global c,d
    c=a+b
    d=a-b
cal(c,d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       5     c=a+b
#       6     d=a-b
# ----> 7 cal(c,d)
#
# NameError: name 'c' is not defined
